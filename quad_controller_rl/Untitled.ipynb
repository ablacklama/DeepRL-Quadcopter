# %%
import pandas as pd
from glob import glob
# %matplotlib inline
names = glob("out/*.csv")
names.sort()
for name in names:
    print(name)
# Out:
# out/stats_2018-03-09_10-48-08.csv
# out/stats_2018-03-09_10-50-24.csv
# out/stats_2018-03-09_10-57-31.csv
# out/stats_2018-03-09_14-51-42.csv
# out/stats_2018-03-09_17-28-50.csv
# out/stats_2018-03-09_17-41-14.csv
# out/stats_2018-03-09_17-57-42.csv

# %%
filename = names[-1]

# %%
df_stats = pd.read_csv(filename)
df_stats[['total_reward']].plot(title="Episode Rewards")
